# %%
from bs4 import BeautifulSoup
import pandas as pd
from IPython.core.display import display, HTML
import pandas as pd
import requests

# %%
URL = "https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2016-Results"

# %%
response = requests.post(URL)
response.status_code
# Out:
# 200

# %%
response.headers["content-type"]
# Out:
# 'text/html; charset=utf-8'

# %%
response.content
# Out:
# b'\n<!DOCTYPE html>\n<!--[if IE 9]><html lang="en" class="ie9 no-js"><![endif]-->\n<!--[if !IE]><!-->\n<html lang="en">\n<!--<![endif]-->\n<head>\n<script src="/cdn-cgi/apps/head/u7S6kWy3Cysuih2qEtS0XdJlwiE.js"></script><link href="/styles/vendor.min.css" rel="stylesheet" />\n<link href="/styles/rnr.min.css" rel="stylesheet" />\n<meta charset="utf-8" />\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta http-equiv="Content-type" content="text/html; charset=utf-8">\n<meta content="width=device-width, initial-scale=1.0" name="viewport" />\n<title> | Rock n Roll Marathon Series | Marathon Half Marathon Events</title>\n<meta property="og:title" content="" />\n<meta property="og:image" content="" />\n<meta property="og:description" content="" />\n<meta property="og:url" content="https://www.runrocknroll.com:443/en/Events/Nashville/The Races/Marathon/2016 Results" />\n\n<script>\r\n        (function (w, d, s, l, i) {\r\n            w[l] = w[l] || [];\r\n            w[l].push({\r
# ...

# %%
soup = BeautifulSoup(response.content, "html.parser")
soup.find(attrs={"class": "race-search-main"}) \
    .find("table")
# Out:
# <table class="table table-responsive table-bordered">
# <tr>
# <th class="table-place">Overall</th>
# <th class="table-place">Bib</th>
# <th class="table-name">Name</th>
# <th class="table-time">Time</th>
# </tr>
# <tr>
# <td>1</td>
# <td>1</td>
# <td><a href="/en/Events/Nashville/The-Races/Marathon/2016-Results/Athlete?id=1">Scott Wietecha</a></td>
# <td>02:25:42</td>
# </tr>
# <tr>
# <td>2</td>
# <td>3</td>
# <td><a href="/en/Events/Nashville/The-Races/Marathon/2016-Results/Athlete?id=3">Brian Shelton</a></td>
# <td>02:34:43</td>
# </tr>
# <tr>
# <td>3</td>
# <td>1047</td>
# <td><a href="/en/Events/Nashville/The-Races/Marathon/2016-Results/Athlete?id=1047">Christopher Capps</a></td>
# <td>02:38:43</td>
# </tr>
# <tr>
# <td>4</td>
# <td>1052</td>
# <td><a href="/en/Events/Nashville/The-Races/Marathon/2016-Results/Athlete?id=1052">Jason Grimes</a></td>
# <td>02:45:06</td>
# </tr>
# <tr>
# <td>5</td>
# <td>1046</td>
# ...

# %%
full2016all = []
x = 1
while x < 155:
  # baseURL = "https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2016-Results"
    URL ='https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2016-Results?gender=&agegroup=&bib=&firstname=&lastname=&page={}'.format(x)
    response = requests.post(URL)
    soup =BeautifulSoup(response.content, "html.parser")
    full2016page = soup.find(attrs = {"class": "race-search-main"}).find("table")
    full2016_list = pd.read_html(str(full2016page))
    full2016_list = full2016_list[0]
    full2016all.append(full2016_list)
    x += 1

# %%
full2016df = pd.concat(full2016all)
full2016df
# Out:
#     Overall    Bib                     Name      Time
# 0         1      1           Scott Wietecha  02:25:42
# 1         2      3            Brian Shelton  02:34:43
# 2         3   1047        Christopher Capps  02:38:43
# 3         4   1052             Jason Grimes  02:45:06
# 4         5   1046              David Adams  02:47:28
# ..      ...    ...                      ...       ...
# 12    99999  21159               Beth Lyons  00:00:00
# 13    99999  25061          Aleksei Stevens  00:00:00
# 14    99999   6047          Lizzie Ziccardi  00:00:00
# 15    99999   2052             Adam Pastors  00:00:00
# 16    99999   2107  Anastasiya Christiansen  00:00:00
#
# [3842 rows x 4 columns]

# %%
full2017all = []
x = 1
while x < 148:
  # baseURL = "https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2017-Results"
    URL ='https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2017-Results?gender=&agegroup=&bib=&firstname=&lastname=&page={}'.format(x)
    response = requests.post(URL)
    soup =BeautifulSoup(response.content, "html.parser")
    full2017page = soup.find(attrs = {"class": "race-search-main"}).find("table")
    full2017_list = pd.read_html(str(full2017page))
    full2017_list = full2017_list[0]
    full2017all.append(full2017_list)
    x += 1

# %%
full2017df = pd.concat(full2017all)
full2017df
# Out:
#     Overall    Bib             Name      Time
# 0         1      1   Scott Wietecha  02:40:25
# 1         2   1145     Ryan Regnier  02:56:28
# 2         3   1147   Daniel Everett  03:00:55
# 3         4   1029    Khris Vickroy  03:04:47
# 4         5   1119   Marcus Dilallo  03:04:53
# ..      ...    ...              ...       ...
# 21    99999   1185       Ernest Lee  00:00:00
# 22    99999   8038  Allison Alfonso  00:00:00
# 23    99999  26069   Justin Wehring  00:00:00
# 24    99999   8111   Timothy Forbes  00:00:00
# 0     99999   2084    Thomas Hansen  00:00:00
#
# [3651 rows x 4 columns]

# %%
full2018all = []
x = 1
while x < 86:
  # baseURL = "https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2018-Results"
    URL ='https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2018-Results?gender=&agegroup=&bib=&firstname=&lastname=&page={}'.format(x)
    response = requests.post(URL)
    soup =BeautifulSoup(response.content, "html.parser")
    full2018page = soup.find(attrs = {"class": "race-search-main"}).find("table")
    full2018_list = pd.read_html(str(full2018page))
    full2018_list = full2018_list[0]
    full2018all.append(full2018_list)
    x += 1

# %%
full2018df = pd.concat(full2018all)
full2018df
# Out:
#     Overall    Bib             Name      Time
# 0         1      1   Scott Wietecha  02:28:16
# 1         2      3     Garang Madut  02:29:52
# 2         3  33442       Kevin Fink  02:38:59
# 3         4  33441    Andrew Hodges  02:43:59
# 4         5  30028  Nicholas Aubert  02:48:11
# ..      ...    ...              ...       ...
# 10    99999  33654      Jeff Ekkart  00:00:00
# 11    99999  31170   Austin Perkins  00:00:00
# 12    99999  30482      David Ramos  00:00:00
# 13    99999  33461   Emily Eagerton  00:00:00
# 14    99999  31515  Tony Quernemoen  00:00:00
#
# [2115 rows x 4 columns]

# %%
full2019all = []
x = 1
while x < 114:
  # baseURL = "https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2019-Results"
    URL ='https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2019-Results?gender=&agegroup=&bib=&firstname=&lastname=&page={}'.format(x)
    response = requests.post(URL)
    soup =BeautifulSoup(response.content, "html.parser")
    full2019page = soup.find(attrs = {"class": "race-search-main"}).find("table")
    full2019_list = pd.read_html(str(full2019page))
    full2019_list = full2019_list[0]
    full2019all.append(full2019_list)
    x += 1

# %%
full2019df = pd.concat(full2019all)
full2019df
# Out:
#     Overall    Bib                Name      Time
# 0         1  30001      Travis Peruski  01:37:54
# 1         2      1      Scott Wietecha  02:34:59
# 2         3      4       Jordan Wilson  02:35:24
# 3         4  30034      Steelton Flynn  02:39:59
# 4         5  30035        Thomas Ellis  02:42:09
# ..      ...    ...                 ...       ...
# 6     99999  32577     Brandon Trammel  00:00:00
# 7     99999  32497        Brian Miller  00:00:00
# 8     99999  32829  Stephanie Whitaker  00:00:00
# 9     99999  30158       Darren Guffey  00:00:00
# 10    99999  32183      Clarisa Horton  00:00:00
#
# [2811 rows x 4 columns]

# %%
half_full2019all = []
x = 1
while x < 691:
  # baseURL = "https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2019-Results"
    URL ='https://www.runrocknroll.com/Events/Nashville/The-Races/Half-Marathon/2019-Results?gender=&agegroup=&bib=&firstname=&lastname=&page={}'.format(x)
    response = requests.post(URL)
    soup =BeautifulSoup(response.content, "html.parser")
    half_full2019page = soup.find(attrs = {"class": "race-search-main"}).find("table")
    half_full2019_list = pd.read_html(str(half_full2019page))
    half_full2019_list = half_full2019_list[0]
    half_full2019all.append(half_full2019_list)
    x += 1

# %%
half_full2019df = pd.concat(half_full2019all)
half_full2019df
# Out:
#     Overall   Bib              Name      Time
# 0         1    31       Nick French  01:10:03
# 1         2    33      Ian Bordelon  01:12:15
# 2         3    32     Chris Demetra  01:12:52
# 3         4  1025      Grayson Reid  01:15:10
# 4         5    34      Jason Vincze  01:17:01
# ..      ...   ...               ...       ...
# 6     99999  1014      Ian Bordelon  00:00:00
# 7     99999  1012      Nick Gehlsen  00:00:00
# 8     99999  6295  Arsenio Franklin  00:00:00
# 9     99999  4922         Matt Lang  00:00:00
# 10    99999  1528        Kyle Eason  00:00:00
#
# [17236 rows x 4 columns]

# %%
half_full2018all = []
x = 1
while x < 599:
  # baseURL = "https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2018-Results"
    URL ='https://www.runrocknroll.com/Events/Nashville/The-Races/Half-Marathon/2018-Results?gender=&agegroup=&bib=&firstname=&lastname=&page={}'.format(x)
    response = requests.post(URL)
    soup =BeautifulSoup(response.content, "html.parser")
    half_full2018page = soup.find(attrs = {"class": "race-search-main"}).find("table")
    half_full2018_list = pd.read_html(str(half_full2018page))
    half_full2018_list = half_full2018_list[0]
    half_full2018all.append(half_full2018_list)
    x += 1

# %%
half_full2018df = pd.concat(half_full2018all)
half_full2018df
# Out:
#     Overall    Bib             Name      Time
# 0         1    103   Roosevelt Cook  01:09:25
# 1         2    107     Lucas Cotter  01:09:51
# 2         3    105      Nick French  01:10:38
# 3         4    106     Jason Vincze  01:11:50
# 4         5    104    Joseph Elsakr  01:13:28
# ..      ...    ...              ...       ...
# 10    14935   8337  Kayleah Maddock  06:04:28
# 11    14937  32614    Kim Donaldson  06:05:35
# 12    14938  31720    Pamela Hagens  06:12:15
# 13    14939  33664      Fatima Rego  06:12:24
# 14    14940  33532      Annie Friar  06:26:37
#
# [14940 rows x 4 columns]

# %%
half_full2017all = []
x = 1
while x < 893:
  # baseURL = "https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2017-Results"
    URL ='https://www.runrocknroll.com/Events/Nashville/The-Races/Half-Marathon/2017-Results?gender=&agegroup=&bib=&firstname=&lastname=&page={}'.format(x)
    response = requests.post(URL)
    soup =BeautifulSoup(response.content, "html.parser")
    half_full2017page = soup.find(attrs = {"class": "race-search-main"}).find("table")
    half_full2017_list = pd.read_html(str(half_full2017page))
    half_full2017_list = half_full2017_list[0]
    half_full2017all.append(half_full2017_list)
    x += 1

# %%
half_full2017df = pd.concat(half_full2017all)
half_full2017df
# Out:
#     Overall    Bib              Name      Time
# 0         1    202     Tyler Andrews  01:10:58
# 1         2    204       Bill Martin  01:11:25
# 2         3    206       Nick French  01:11:42
# 3         4    201    Roosevelt Cook  01:13:20
# 4         5   1655       Erick Kigen  01:14:56
# ..      ...    ...               ...       ...
# 12    99999  37356     Joseph Holder  00:00:00
# 13    99999  28230       Beth Fritch  00:00:00
# 14    99999   2618     Kevin Huffman  00:00:00
# 15    99999  21283    Harmon Roberts  00:00:00
# 16    99999  11428  Coreen Donaldson  00:00:00
#
# [22292 rows x 4 columns]

# %%
half_full2016all = []
x = 1
while x < 899:
  # baseURL = "https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2016-Results"
    URL ='https://www.runrocknroll.com/Events/Nashville/The-Races/Half-Marathon/2016-Results?gender=&agegroup=&bib=&firstname=&lastname=&page={}'.format(x)
    response = requests.post(URL)
    soup =BeautifulSoup(response.content, "html.parser")
    half_full2016page = soup.find(attrs = {"class": "race-search-main"}).find("table")
    half_full2016_list = pd.read_html(str(half_full2016page))
    half_full2016_list = half_full2016_list[0]
    half_full2016all.append(half_full2016_list)
    x += 1

# %%
half_full2016df = pd.concat(half_full2016all)
half_full2016df

# %%
fullAllYearsdf = pd.concat([full2016df, full2017df, full2018df,full2019df], ignore_index=True, sort=False)

# %%
halfAllYearsdf = pd.concat([half_full2016df, half_full2017df, half_full2018df,half_full2019df], ignore_index=True, sort=False)

# %%
fullALLYearsdf.to_csv('../fullALLYearsdf.csv')

# %%
halfALLYearsdf.to_csv('../halfALLYearsdf.csv')

# %%
half_full2016df.to_csv('../half_full2016df.csv')
half_full2017df.to_csv('../half_full2017df.csv')
half_full2018df.to_csv('../half_full2018df.csv')
half_full2019df.to_csv('../half_full2019df.csv')

# %%
full2016df.to_csv('../full2016df.csv')
full2017df.to_csv('../full2017df.csv')
full2018df.to_csv('../full2018df.csv')
full2019df.to_csv('../full2019df.csv')

# %%
with open("../assets/website.html") as website_file:
    website_contents = website_file.read()
    
website_contents

# %%
soup = BeautifulSoup(website_contents, "html.parser")
soup.title

# %%
dashboard_cards_soup = soup.find("div", attrs={"class": "da-dashboardCards"})

dashboard_cards_soup

# %%
dashboard_cards = dashboard_cards_soup.findAll(recursive=False)

dashboard_cards

# %%
user_card = dashboard_cards[-1]

user_card

# %%
feeds = soup.find("div", attrs={"class": "da-feeds"})

feeds

# %%
dataframes = pd.read_html(str(feeds))
dataframes

# %%
feed_dataframe = dataframes[0]
feed_dataframe
